# %%
import matplotlib.pyplot as plt
import math
import pickle 
# import main.py
import numpy
from main import word_postings_element, doc_element

# %%
  
  x1 = numpy.array([84998,173931,262347,344451])
  y1 = numpy.array([6667,9371,10985,12358])
  x=[]
  y=[]
  for i in range(len(x1)):
    x.append(math.log(x1[i],10))
    y.append(math.log(y1[i],10))
  x = numpy.array(x)
  y = numpy.array(y)
  t1, t2 = numpy.polyfit(x, y, 1, w=numpy.sqrt(y))
  line_y = t1 * x + t2 
    
  plt.suptitle("With stemmer")
  plt.plot(x, y)
  plt.plot(x, line_y)
  plt.show()

# %%
  
  x1 = numpy.array([84998,173931,262347,344451])
  y1 = numpy.array([9151,13311,15918,17988])
  x=[]
  y=[]
  for i in range(len(x1)):
    x.append(math.log(x1[i],10))
    y.append(math.log(y1[i],10))
  x = numpy.array(x)
  y = numpy.array(y)
  t1, t2 = numpy.polyfit(x, y, 1, w=numpy.sqrt(y))
  line_y = t1 * x + t2 
    
  plt.suptitle("Without stemmer")
  plt.plot(x, y)
  plt.plot(x, line_y)
  plt.show()
